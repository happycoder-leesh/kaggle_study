# %%
import pandas as pd

df = pd.read_csv('CarPrice_Assignment.csv')

df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.drop(['CarName', 'car_ID'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   fueltype          205 non-null    object
#  2   aspiration        205 non-null    object
#  3   doornumber        205 non-null    object
#  4   carbody           205 non-null    object
#  5   drivewheel        205 non-null    object
#  6   enginelocation    205 non-null    object
#  7   wheelbase         205 non-null    float64
#  8   carlength         205 non-null    float64
#  9   carwidth          205 non-null    float64
#  10  carheight         205 non-null    float64
#  11  curbweight        205 non-null    int64
#  12  enginetype        205 non-null    object
#  13  cylindernumber    205 non-null    object
#  14  enginesize        205 non-null    int64
#  15  fuelsystem        205 non-null    object
# ...

# %%
#df_new = pd.get_dummies(df, columns=['fueltype', 'drivewheel', 'aspiration', 'doornumber', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'])
#df_new.info()

# %%
#df_new.drop(['carbody'], axis=1, inplace=True)

# %%
df.corr(method='pearson')
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt

plt.figure(figsize = (15,8))
sb.heatmap(data = df.corr(), fmt='.2f', annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df.drop(['curbweight', 'horsepower', 'carwidth', 'symboling', 'carheight', 'stroke', 'compressionratio', 'peakrpm'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fueltype        205 non-null    object
#  1   aspiration      205 non-null    object
#  2   doornumber      205 non-null    object
#  3   carbody         205 non-null    object
#  4   drivewheel      205 non-null    object
#  5   enginelocation  205 non-null    object
#  6   wheelbase       205 non-null    float64
#  7   carlength       205 non-null    float64
#  8   enginetype      205 non-null    object
#  9   cylindernumber  205 non-null    object
#  10  enginesize      205 non-null    int64
#  11  fuelsystem      205 non-null    object
#  12  boreratio       205 non-null    float64
#  13  citympg         205 non-null    int64
#  14  highwaympg      205 non-null    int64
#  15  price           205 non-null    float64
# dtypes: float64(4), int64(3), object(9)
# ...

# %%
df_new = pd.get_dummies(df, columns=['fueltype', 'drivewheel', 'aspiration', 'doornumber', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'])
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   carbody                205 non-null    object
#  1   wheelbase              205 non-null    float64
#  2   carlength              205 non-null    float64
#  3   enginesize             205 non-null    int64
#  4   boreratio              205 non-null    float64
#  5   citympg                205 non-null    int64
#  6   highwaympg             205 non-null    int64
#  7   price                  205 non-null    float64
#  8   fueltype_diesel        205 non-null    uint8
#  9   fueltype_gas           205 non-null    uint8
#  10  drivewheel_4wd         205 non-null    uint8
#  11  drivewheel_fwd         205 non-null    uint8
#  12  drivewheel_rwd         205 non-null    uint8
#  13  aspiration_std         205 non-null    uint8
# ...

# %%
df_new.drop(['carbody'], axis=1, inplace=True)

# %%
plt.figure(figsize = (30, 10))
sb.heatmap(data = df_new.corr(), fmt='.2f', annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df_infor = df_new[['wheelbase', 'carlength', 'enginesize', 'boreratio', 'citympg', 'highwaympg', 'drivewheel_fwd', 'drivewheel_rwd', 'cylindernumber_four', 'price']]
df_infor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wheelbase            205 non-null    float64
#  1   carlength            205 non-null    float64
#  2   enginesize           205 non-null    int64
#  3   boreratio            205 non-null    float64
#  4   citympg              205 non-null    int64
#  5   highwaympg           205 non-null    int64
#  6   drivewheel_fwd       205 non-null    uint8
#  7   drivewheel_rwd       205 non-null    uint8
#  8   cylindernumber_four  205 non-null    uint8
#  9   price                205 non-null    float64
# dtypes: float64(4), int64(3), uint8(3)
# memory usage: 11.9 KB

# %%
sb.scatterplot(data=df, x='wheelbase', y='price', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
sb.scatterplot(data=df, x='carlength', y='price', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
sb.scatterplot(data=df, x='enginesize', y='price', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = ['enginesize', 'boreratio', 'citympg', 'highwaympg', 'drivewheel_fwd', 'drivewheel_rwd', 'cylindernumber_four']
df_infor[features] = scaler.fit_transform(df_infor[features])
# Out:
# C:\Users\USER\anaconda3\envs\kaggle_study\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
df_infor[features].head()
# Out:
#    wheelbase  carlength  enginesize  boreratio   citympg  highwaympg  \
# 0  -1.690772  -0.426521    0.074449   0.519071 -0.646553   -0.546059
# 1  -1.690772  -0.426521    0.074449   0.519071 -0.646553   -0.546059
# 2  -0.708596  -0.231513    0.604046  -2.404880 -0.953012   -0.691627
# 3   0.173698   0.207256   -0.431076  -0.517266 -0.186865   -0.109354
# 4   0.107110   0.207256    0.218885  -0.517266 -1.106241   -1.273900
#
#    drivewheel_fwd  drivewheel_rwd  cylindernumber_four
# 0       -1.188177        1.302831             0.537874
# 1       -1.188177        1.302831             0.537874
# 2       -1.188177        1.302831            -1.859172
# 3        0.841625       -0.767559             0.537874
# 4       -1.188177       -0.767559            -1.859172

# %%
from sklearn.model_selection import train_test_split

features = ['enginesize', 'boreratio', 'citympg', 'highwaympg', 'drivewheel_fwd', 'drivewheel_rwd', 'cylindernumber_four']

X = df_infor[features]
y = df_new['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((164, 7), (164,))

# %%
X_test.shape, y_test.shape
# Out:
# ((41, 7), (41,))

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, KFold

model = XGBRegressor(max_depth=4)
model.fit(X_train, y_train, eval_metric='rmse')
kfold = KFold(n_splits=10, shuffle=True)
kf_cv_scores = cross_val_score(model, X_train, y_train, cv=kfold )
print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
# Out:
# K-fold CV average score: 0.81

# %%
print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# 0.9832440772405915
# 0.92693079656977

# %%
import numpy as np

pred = model.predict(X_test)
print(np.sqrt(mean_squared_error(pred, y_test)))
# Out:
# 2378.3926563468663

# %%
x_ax = range(len(y_test))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, y_test, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
from xgboost import plot_importance

plot_importance(model)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>
